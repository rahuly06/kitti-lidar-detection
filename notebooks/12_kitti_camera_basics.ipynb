# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('../data/KITTI/training/image_2/000000.png')

# %%
# 2. Check if the image loaded successfully
if image is None:
    print("Error: Could not open or find the image.")
else:
    # 3. Display the image in a window
    cv2.imshow('Loaded Image', image)

    # 4. Wait for a key press and close the window
    cv2.waitKey(8000)
    cv2.destroyAllWindows()
# Out:
# QFontDatabase: Cannot find font directory /home/rahul/projects/kitti-lidar-detector/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/rahul/projects/kitti-lidar-detector/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/rahul/projects/kitti-lidar-detector/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/rahul/projects/kitti-lidar-detector/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/rahul/projects/kitti-lidar-detector/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.

# %%
image.shape
# Out:
# (370, 1224, 3)

# %%
plt.imshow(image)

# %%
Image(image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 Image(image)
#
# NameError: name 'Image' is not defined

# %%
import cv2
import sys

s = 0
if len(sys.argv) > 1:
    s = sys.argv[1]

source = cv2.VideoCapture(s)

win_name = 'Camera Preview'
cv2.namedWindow(win_name, cv2.WINDOW_NORMAL)

while cv2.waitKey(1) != 27: # Escape
    has_frame, frame = source.read()
    if not has_frame:
        break
    cv2.imshow(win_name, frame)

source.release()
cv2.destroyWindow(win_name)
